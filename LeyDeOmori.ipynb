# %%
import pandas as pd

url = 'https://github.com/seismomat/HerramientasComputacionales/blob/main/SSNMX_catalogo_20170907_20170915.csv'
df = pd.read_csv(url, index_col=0,sep=';')
print(df.head(5))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       1 import pandas as pd
#       3 url = 'https://github.com/seismomat/HerramientasComputacionales/blob/main/SSNMX_catalogo_20170907_20170915.csv'
# ----> 4 df = pd.read_csv(url, index_col=0,sep=';')
#       5 print(df.head(5))
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
