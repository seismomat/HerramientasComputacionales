# %%
class calculadora:
	
	def __init__(self):
		self.dato1=2
		self.dato2=3
		self.dato3=3

	def prueba(self):
		print(self.dato1)

	def imprimir(self):
		print(self.dato1)
        
	def sumar(self):
		print(self.dato1+self.dato2)
